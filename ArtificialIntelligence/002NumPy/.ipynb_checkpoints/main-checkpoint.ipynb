# %%
# 导包
import numpy as np

# %% [markdown]
# # 1.Numpy的属性介绍

# %%
# numpy的数组 => ndarray， 他是多维的，并且是固定类型的，主要用于矩阵运算

arr1 = np.arange(15)

print(arr1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # numpy的数组 => ndarray， 他是多维的，并且是固定类型的，主要用于矩阵运算
# ----> 3 arr1 = np.arange(15)
#       5 print(arr1)
#
# NameError: name 'np' is not defined
